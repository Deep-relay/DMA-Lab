# %%
import pandas as pd
import numpy as np
from functools import reduce
data=pd.read_csv('./Colleges.csv')
data.head(10)
# Out:
#    Overall Rank                              School State  \
# 0           1.0  California Institute of Technology    CA
# 1           2.0                     Rice University    TX
# 2           3.0                    Williams College    MA
# 3           4.0                  Swarthmore College    PA
# 4           5.0                     Amherst College    MA
# 5           6.0                      Webb Institute    NY
# 6           7.0                     Yale University    CT
# 7           8.0       Washington and Lee University    VA
# 8           9.0                  Harvard University    MA
# 9          10.0                 Stanford University    CA
#
#    Undergrad. Enrollment Admission Rate *SAT or ACT  Student/faculty Ratio  \
# 0                  939.0            21%     99/100%                    3.0
# 1                 2787.0            24%      89/92%                    5.0
# 2                 1985.0            23%      93/93%                    8.0
# 3                 1479.0            24%      94/98%                    8.0
# 4                 1618.0            18%      94/92%                    9.0
# 5                   67.0            42%    100/100%                    7.0
# 6                 5339.0             8%      96/97%                    7.0
# 7                 1750.0            31%      89/89%                   11.0
# 8                 6637.0            11%    90*/90*%                    8.0
# 9                 7360.0            13%      93/95%                    7.0
#
#   4-year Grad. Rate 6-year Grad. Rate  Quality Rank Total Costs  \
# 0               71%               85%          10.0    $32,682
# 1               68%               89%          19.0    $28,350
# 2               89%               94%           1.0    $36,550
# 3               86%               92%           4.0    $38,676
# 4               84%               94%           5.0    $38,492
# 5               79%               83%          39.0     $8,079
# 6               88%               95%           3.0    $38,432
# 7               86%               89%          30.0    $30,225
# 8               86%               97%           8.0    $38,831
# 9               77%               93%           6.0    $38,875
#
#   Cost After Need-based Aid Need Met Aid From Grants  \
# 0                  $10,981      100%             93%
# 1                  $14,779      100%             88%
# 2                  $14,737      100%             89%
# 3                  $17,386      100%             85%
# 4                  $14,453      100%             92%
# 5                   $5,579       20%            100%
# 6                  $15,729      100%             89%
# 7                  $15,452       99%             87%
# 8                  $17,456      100%             90%
# 9                  $17,746      100%             86%
#
#   Cost After Non-Need-Based Aid Non-Need-Based Aid+ Average Debt  Cost Rank
# 0                      $18,553                  15%     $10,244         4.0
# 1                      $22,418                  34%     $12,705         5.0
# 2                      $33,251                  NaN     $12,316        26.0
# 3                      $11,404                   2%     $12,759        21.0
# 4                      $33,411                  NaN     $11,544        38.0
# 5                       $8,079                 100%      $5,700         1.0
# 6                      $38,432                  NaN     $19,228        53.0
# 7                      $22,063                  31%     $15,634         9.0
# 8                      $33,201                  NaN     $10,465        46.0
# 9                      $33,709                  NaN     $15,782        62.0

# %% [markdown]
# #### Cleaning the Numeric Attributes

# %%
def clean(item):
  if type(item) is float and np.isnan(item):
    return np.nan
  if type(item) is float:
    return item
  if item.find('*')!=-1:
    if item.find('/')!=-1:
      SAT=item[:item.find('*')]
      ACT=item[item.find('/')+1:item.find('*', item.find('*')+1)]
      return max(int(SAT), int(ACT))
    else:
      return int(item[:item.find('*')])
  if item.find('/')!=-1:
    SAT=item[:item.find('/')]
    ACT=item[item.find('/')+1:item.find('%')]
    return max(int(SAT), int(ACT))
  if(item.find('%')):
    return int(item[:item.find('%')])
data['*SAT or ACT']=data['*SAT or ACT'].apply(clean)
data['*SAT or ACT'].fillna(data['*SAT or ACT'].median(), inplace=True)
data.head(20)
# Out:
# <ipython-input-135-56c39b996e42>:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data
# 17               84.0               88.0          32.0      37419.0
# 18               81.0               87.0          22.0      37870.0
# 19               89.0               92.0          20.0      38928.0
#
#     Cost After Need-based Aid  Need Met  Aid From Grants  \
# 0                     10981.0     100.0             93.0
# 1                     14779.0     100.0             88.0
# 2                     14737.0     100.0             89.0
# 3                     17386.0     100.0             85.0
# 4                     14453.0     100.0             92.0
# 5                      5579.0      20.0            100.0
# 6                     15729.0     100.0             89.0
# 7                     15452.0      99.0             87.0
# 8                     17456.0     100.0             90.0
# 9                     17746.0     100.0             86.0
# 10                    18325.0     100.0             94.0
# 11                    19609.0     100.0             85.0
# 12                    17411.0     100.0             80.0
# 13                    19657.0     100.0             73.0
# 14                    17778.0     100.0             86.0
# 15                    19996.0     100.0             80.0
# 16                    21455.0     100.0             82.0
# 17                    17526.0     100.0             88.0
# 18                    19404.0     100.0             78.0
# 19                    17826.0     100.0             90.0
#
#     Cost After Non-Need-Based Aid  Non-Need-Based Aid+  Average Debt  \
# 0                         18553.0                 15.0       10244.0
# 1                         22418.0                 34.0       12705.0
# 2                         33251.0                 26.0       12316.0
# 3                         11404.0                  2.0       12759.0
# 4                         33411.0                 26.0       11544.0
# 5                          8079.0                100.0        5700.0
# 6                         38432.0                 26.0       19228.0
# 7                         22063.0                 31.0       15634.0
# 8                         33201.0                 26.0       10465.0
# 9                         33709.0                 26.0       15782.0
# 10                        40169.0                 26.0       12000.0
# 11                        30337.0                 26.0       22855.0
# 12                        35702.0                 26.0       15600.0
# 13                        23615.0                 19.0       17675.0
# 14                        39493.0                 26.0       15331.0
# 15                        26599.0                  6.0       20025.0
# 16                        28630.0                 35.0       13697.0
# 17                        32919.0                 26.0       15697.0
# 18                        34669.0                 26.0       17170.0
# 19                        38928.0                 26.0       15253.0
#
#     Cost Rank
# 0         4.0
# 1         5.0
# 2        26.0
# 3        21.0
# 4        38.0
# 5         1.0
# 6        53.0
# 7         9.0
# 8        46.0
# 9        62.0
# 10       59.0
# 11       82.0
# 12       43.0
# 13       54.0
# 14       65.0
# 15       68.0
# 16       37.0
# 17       35.0
# 18       64.0
# 19       66.0

# %% [markdown]
# #### Cleaning cost based Attributes

# %%
costBased=[]
for attribute in list(data):
  if type(data[attribute][0]) is str and data[attribute][0][0]=='$':
    costBased.append(attribute)
def removeDollarOrComma(item):
  print(item)
  if type(item) is float and np.isnan(item):
    return np.nan
  item.strip()
  item=item[1:]
  item=float(''.join(item.split(',')))
  return item
for attribute in costBased:
  data[attribute]=data[attribute].apply(removeDollarOrComma)
  data[attribute].fillna(data[attribute].median(), inplace=True)
data.head(102)
# data.isnull()
# Out:
#      Overall Rank                              School State  \
# 0             1.0  California Institute of Technology    CA
# 1             2.0                     Rice University    TX
# 2             3.0                    Williams College    MA
# 3             4.0                  Swarthmore College    PA
# 4             5.0                     Amherst College    MA
# ..            ...                                 ...   ...
# 97           98.0    Rensselaer Polytechnic Institute    NY
# 98           99.0              Sarah Lawrence College    NY
# 99          100.0    The George Washington University    DC
# 100           NaN                                 NaN   NaN
# 101           NaN                                 NaN   NaN
#
#      Undergrad. Enrollment  Admission Rate  *SAT or ACT  \
# 0                    939.0            21.0        100.0
# 1                   2787.0            24.0         92.0
# 2                   1985.0            23.0         93.0
# 3                   1479.0            24.0         98.0
# 4                   1618.0            18.0         94.0
# ..                     ...             ...          ...
# 97                  5139.0            70.0         92.0
# 98                  1226.0            40.0         79.0
# 99                 10328.0            40.0         72.0
# 100                    NaN            39.5         88.0
# 101                    NaN            39.5         88.0
#
#      Student/faculty Ratio  4-year Grad. Rate  6-year Grad. Rate  \
# 0                      3.0               71.0               85.0
# 1                      5.0               68.0               89.0
# 2                      8.0               89.0               94.0
# 3                      8.0               86.0               92.0
# 4                      9.0               84.0               94.0
# ..                     ...                ...                ...
# 97                    17.0               48.0               75.0
# 98                     6.0               51.0               66.0
# 99                    14.0               62.0               73.0
# 100                    NaN               76.0               84.0
# 101                    NaN               76.0               84.0
#
#      Quality Rank  Total Costs  Cost After Need-based Aid  Need Met  \
# 0            10.0      32682.0                    10981.0     100.0
# 1            19.0      28350.0                    14779.0     100.0
# 2             1.0      36550.0                    14737.0     100.0
# 3             4.0      38676.0                    17386.0     100.0
# 4             5.0      38492.0                    14453.0     100.0
# ..            ...          ...                        ...       ...
# 97           84.0      39200.0                    22360.0      90.0
# 98           94.0      42121.0                    22847.0      94.0
# 99           98.0      40240.0                    25866.0      94.0
# 100           NaN      37345.5                    18706.5     100.0
# 101           NaN      37345.5                    18706.5     100.0
#
#      Aid From Grants  Cost After Non-Need-Based Aid  Non-Need-Based Aid+  \
# 0               93.0                        18553.0                 15.0
# 1               88.0                        22418.0                 34.0
# 2               89.0                        33251.0                 26.0
# 3               85.0                        11404.0                  2.0
# 4               92.0                        33411.0                 26.0
# ..               ...                            ...                  ...
# 97              74.0                        28411.0                 45.0
# 98              73.0                        33610.0                 26.0
# 99              56.0                        29916.0                 25.0
# 100             78.0                        28337.0                 26.0
# 101             78.0                        28337.0                 26.0
#
#      Average Debt  Cost Rank
# 0         10244.0        4.0
# 1         12705.0        5.0
# 2         12316.0       26.0
# 3         12759.0       21.0
# 4         11544.0       38.0
# ..            ...        ...
# 97        24590.0       94.0
# 98        14864.0       89.0
# 99            0.0       96.0
# 100       15753.5        NaN
# 101       15753.5        NaN
#
# [102 rows x 18 columns]

# %% [markdown]
# #### Cleaning other Rates

# %%
rateBased=[]
for attribute in list(data):
  if type(data[attribute][0]) is str and data[attribute][0][-1]=='%':
    rateBased.append(attribute)
def removePercent(item):
  print(item)
  if (type(item) is str and item[0].isalpha()) or (type(item) is float and np.isnan(item)):
    return np.nan
  item.strip()
  item=item[:-1]
  return float(item)
for attribute in rateBased:
  data[attribute]=data[attribute].apply(removePercent)
  data[attribute].fillna(data[attribute].median(), inplace=True)
